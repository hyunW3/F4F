# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = '2'
os.environ["TF_CPP_MIN_LOG_LEVEL"] = '3'
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as dataset
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy as d_copy
import random

# %%
original_filter_path = "/media/3/Network/filter/pooling4/conv5_1_original.pt"
new_filter_path = "/media/3/Network/filter/pooling4/case13/only_error_input_F4F/conv5_1_train_epoch_007.pt"
new_filter = torch.load(new_filter_path).cpu().detach().numpy()
original_filter = torch.load(original_filter_path).cpu().detach().numpy()

# %%
plt.figure()
plt.imshow
# Out:
# <function matplotlib.pyplot.imshow(X, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, *, filternorm=True, filterrad=4.0, resample=None, url=None, data=None, **kwargs)>

# %%
w = 10
h = 10
cols = 32
rows = 16
# %matplotlib inline
def feature_print(title,img):
    print(title)
    fig = plt.figure(figsize=(64,32))
    ax = []
    for i in range(cols*rows):
        ch = img[i]
        ax.append(fig.add_subplot(rows,cols,i+1))
        ax[-1].set_title(str(i)+"th ch (14x14)")
        plt.imshow(ch)#, cmap='CMRmap')#, vmin=-0.25, vmax=0.25)
        plt.clim(-0.025,0.025)
    #plt.show()
        #plt.tight_layout()
#plt.colorbar()
#plt.imshow(ch_1,cmap='gray')

# %%
number = 2
offset = (new_filter[number]-original_filter[number])
#print(offset.shape)
feature_print("offset with 'after pooling 4 filter -0.025~0.025'",offset)
# Out:
# offset with 'after pooling 4 filter -0.025~0.025'

# %%
new_filter = new_filter[number]
feature_print("new filter with 'after pooling 4 filter -0.025~0.025'",new_filter)
# Out:
# new filter with 'after pooling 4 filter -0.025~0.025'

# %%
original_filter = original_filter[number]
feature_print("new filter with 'after pooling 4 filter -0.025~0.025'",original_filter)
# Out:
# new filter with 'after pooling 4 filter -0.025~0.025'

# %%
# %matplotlib inline
#plt.plot(val[0])
plt.legend(loc='best')
plt.imshow(val[0])
